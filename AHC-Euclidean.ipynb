# %% [markdown]
# Hi there! This is my first kernel dealing with textual data so any constructive feedabacks are higly appreciated.
#
# This dataset contains data of over 7 topics namely biology, robotics, cryptography, diy, travel, cooking, robotics and physics extracted from Stack Exchange. Each of these topics except physics have been classified as to which topic data belongs. So our task is to do predictions on unseen physics questions.
#
# Since our data won't be related to each other for example tags in travel won't be related to tags in cryptography hence I will be using unsupervised learning on physics dataset which is the test dataset.

# %%
#Importing all the neccesary libraries
import numpy as np 
import pandas as pd 

import os
print(os.listdir("input"))

import regex as re
import string
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import WordNetLemmatizer

# viz
import matplotlib.pyplot as plt
# %matplotlib inline
import sys

# feature extraction
from sklearn.feature_extraction.text import TfidfVectorizer
import nltk
from nltk.stem import WordNetLemmatizer 

# for clustering
from scipy.cluster.hierarchy import ward, dendrogram, fcluster, single, complete, average, weighted
from sklearn.metrics.pairwise import cosine_similarity,euclidean_distances
from sklearn.metrics import jaccard_score
from sklearn.metrics import silhouette_score
# Out:
# ['.ipynb_checkpoints', '951967.zip', 'Bug report 10.csv', 'Bug report 100.csv', 'Bug report.csv', 'JIRA-ALL.csv', 'JIRA-BUG.csv', 'JIRA.csv', 'preprocessed_data.csv']

# %% [markdown]
# Making dictionary to put all the data in the same hood.

# %%
data=pd.read_csv('Input/JIRA-BUG.csv')
data = data.reset_index()
data.head()
# Out:
#    index                                            Summary     Bug Location  \
# 0      0  [Dev][Demo][Admin Portal][Edit Bundle items]: ...     Admin Portal
# 1      1  [Dev][Admin Portal][Create New][Create From ex...     Admin Portal
# 2      2  Duplicate items while using Search items by ke...  Automation Test
# 3      3  [AP] Default language and default region of st...     Admin Portal
# 4      4  [Unity][SDK] Single draft store makes subscrip...              SDK
#
#    Issue key  Issue id Issue Type       Status Project key  \
# 0  CORE-4396     57063        Bug        To Do        CORE
# 1  CORE-4385     57039        Bug  In Progress        CORE
# 2  CORE-4377     57007        Bug        To Do        CORE
# 3  CORE-4366     56971        Bug           QA        CORE
# 4  CORE-4365     56960        Bug        To Do        CORE
#
#           Project name Project type  ... Comment.64 Comment.65  Comment.66  \
# 0  Justice - Core Team     software  ...        NaN        NaN         NaN
# 1  Justice - Core Team     software  ...        NaN        NaN         NaN
# 2  Justice - Core Team     software  ...        NaN        NaN         NaN
# 3  Justice - Core Team     software  ...        NaN        NaN         NaN
# 4  Justice - Core Team     software  ...        NaN        NaN         NaN
#
#   Comment.67 Comment.68 Comment.69 Comment.70 Parent Parent summary  \
# 0        NaN        NaN        NaN        NaN    NaN            NaN
# 1        NaN        NaN        NaN        NaN    NaN            NaN
# 2        NaN        NaN        NaN        NaN    NaN            NaN
# 3        NaN        NaN        NaN        NaN    NaN            NaN
# 4        NaN        NaN        NaN        NaN    NaN            NaN
#
#   Status Category
# 0           To Do
# 1     In Progress
# 2           To Do
# 3     In Progress
# 4           To Do
#
# [5 rows x 220 columns]

# %%
cols_of_interest=["Summary", "Status","Description","Priority","Resolution", "Issue Type", "Bug Location"]
data=data[cols_of_interest]
print(data.shape)
data.head()
# Out:
# (651, 7)
#                                              Summary       Status  \
# 0  [Dev][Demo][Admin Portal][Edit Bundle items]: ...        To Do
# 1  [Dev][Admin Portal][Create New][Create From ex...  In Progress
# 2  Duplicate items while using Search items by ke...        To Do
# 3  [AP] Default language and default region of st...           QA
# 4  [Unity][SDK] Single draft store makes subscrip...        To Do
#
#                                          Description Priority Resolution  \
# 0  This issue occurs on *Add new bundle items.*\n...       P1        NaN
# 1  This issue occurs on Create new Role and Creat...       P1        NaN
# 2  While making script for cleanup, we found that...       P2        NaN
# 3  When we open Stores menu and look at the store...       P1        NaN
# 4  The restriction of single draft store makes su...       P1        NaN
#
#   Issue Type     Bug Location
# 0        Bug     Admin Portal
# 1        Bug     Admin Portal
# 2        Bug  Automation Test
# 3        Bug     Admin Portal
# 4        Bug              SDK

# %%
fig = plt.figure(figsize=(8,6))
data.groupby('Bug Location').Status.count().plot.bar(ylim=0)
plt.show()

# %%
data.Description = data.Description.fillna("0")
data.isnull().sum()
# Out:
# Summary          0
# Status           0
# Description      0
# Priority         0
# Resolution      97
# Issue Type       0
# Bug Location     0
# dtype: int64

# %% [markdown]
# **Text data preprocessing steps**
#
# 1- Data Cleaning(either using regex or BeautifulSoup):
# a) Removing HTML characters.
# b) Removing punctuation.
# c) Decoding encoded data.
# d) Split attached words.
# e) Removing URLs.
# f) Apostrophe removal.
# g) Removing Expressions.
# h) Uppercase & Lowercase letters
# i) Numbers such as amounts and data.
#
# 2- Data Tokenization(using word_tokenize in nltk.tokenize)
# Segregation of text into individual words i.e tokens.
#
# 3- Stopword Removal(using stopwords in nltk.corpus)
# Discarding too common words or words which are not going to be helpful in our analysis.
#
# 4- Stemming(using WordNetLemmatizer in nltk.stem)
# Combining different variants of words into a single parent word that conveys same meaning.
#
# 5-Vectorization (either using TfidVectorizer or Countvectorizer in sklearn.feature_extraction.text or word embeddings) Changing text data into vector format.

# %%
stops = set(stopwords.words("english"))

# %%
data.dtypes
# Out:
# Summary         object
# Status          object
# Description     object
# Priority        object
# Resolution      object
# Issue Type      object
# Bug Location    object
# dtype: object

# %%
dataConcat = pd.DataFrame()
dataConcat = data.Summary +" "+data.Status +" "+ data.Description+" "+data["Bug Location"]
dataConcat.to_csv("./Output/data_concat.csv")

# %%
def clean_Description(content):
#     content = table.Description
    #Converting text to lowercase characters
    content = content.apply(lambda x: x.lower())
    #Removing HTML tags
    content = content.apply(lambda x: re.sub(r'\<[^<>]*\>','',x))
    #Removing any character which does not match to letter,digit or underscore
    content = content.apply(lambda x: re.sub(r'^\W+|\W+$',' ',x))
    #Removing space,newline,tab
    content = content.apply(lambda x: re.sub(r'\s',' ',x))
    #Removing punctuation
    content = content.apply(lambda x: re.sub(r'[^a-zA-Z0-9]',' ',x))
    #Removing numeric
    content = content.apply(lambda x: re.sub(r'[0-9]','',x))
    #Tokenizing data
    content = content.apply(lambda x: word_tokenize(x))
    #Removing stopwords
    content = content.apply(lambda x: [i for i in x if i not in stops])
    type(content)
    return(content)

# %%
# data['bug']
dataClean = pd.DataFrame()
dataClean = clean_Description(dataConcat)
dataClean.head()
# Out:
# 0    [dev, demo, portal, edit, bundle, items, add, ...
# 1    [dev, portal, create, new, create, existing, a...
# 2    [duplicate, items, using, search, items, keywo...
# 3    [ap, default, language, default, region, store...
# 4    [unity, sdk, single, draft, store, makes, subs...
# dtype: object

# %%
# desc = ' '
# for x in data.Description:
#     for y in x:
#         desc+=' '+y

# %%
# plt.figure(figsize=(8,10))
# wc = WordCloud(max_words=1000,random_state=1).generate(desc)
# plt.imshow(wc)
# plt.show()

# %%
dataClean.dtypes
# Out:
# dtype('O')

# %%
wordnet = WordNetLemmatizer()
dataClean = dataClean.apply(lambda x:[wordnet.lemmatize(i,pos='v') for i in x])
dataClean.head()
# Out:
# 0    [dev, demo, portal, edit, bundle, items, add, ...
# 1    [dev, portal, create, new, create, exist, able...
# 2    [duplicate, items, use, search, items, keyword...
# 3    [ap, default, language, default, region, store...
# 4    [unity, sdk, single, draft, store, make, subsc...
# dtype: object

# %% [markdown]
# ## Hierarchical clustering
#
# We experiment with multiple hierarchical clustering criteria:
# * Ward (maximize the decrease in intra-cluster variance with respect to all clusters)
# * Single (move point to cluster of nearest neighbor)
# * Complete (move point to the cluster with minimum distance to farthest point)
#
# Ward clustering yielded reasonable results, as did complete clustering. Many cases Using the single criterion results in a degenerate case.

# %%
# data.Description = ','.join(str(v) for v in data.Description)
# data.head()
# data.fillna('0')
dataClean.dtypes
# Out:
# dtype('O')

# %%
Summary = dataClean.astype(str)
# Summary = str(data.summary)
# data.Summary.astype(str)
Summary.dtypes
# Out:
# dtype('O')

# %%
tfidf_vectorizer = TfidfVectorizer(lowercase=False)

# %%
tfidf_matrix = tfidf_vectorizer.fit_transform(Summary)
tfidf_matrix
# np.savetxt("./Output/tfidf_matrix.csv", tfidf_matrix, delimiter=",")
# Out:
# <651x2107 sparse matrix of type '<class 'numpy.float64'>'
# 	with 16655 stored elements in Compressed Sparse Row format>

# %%
dist = euclidean_distances(tfidf_matrix)
print(dist)
# dist = jaccard_score(tfidf_matrix)
np.savetxt("./Output/dist.csv", dist, delimiter=",")
# Out:
# [[0.         1.31287173 1.3349545  ... 1.39795046 1.39248905 1.38249502]
#  [1.31287173 0.         1.36344068 ... 1.396736   1.3952015  1.39756319]
#  [1.3349545  1.36344068 0.         ... 1.40973147 1.39025427 1.32540703]
#  ...
#  [1.39795046 1.396736   1.40973147 ... 0.         1.36557102 1.37785397]
#  [1.39248905 1.3952015  1.39025427 ... 1.36557102 0.         1.37897424]
#  [1.38249502 1.39756319 1.32540703 ... 1.37785397 1.37897424 0.        ]]

# %% [markdown]
# ## Agglomerative Hierarchical Clustering

# %% [markdown]
# ### Average

# %%
dist = dist - dist.min() # get rid of some pesky floating point errors that give neg. distance
linkage_matrix = average(dist) # replace with complete, single, or other scipy.cluster.hierarchical algorithms
# Out:
# C:\Users\GF\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py:438: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='average', metric='euclidean')

# %% [markdown]
# ## Visualization
#
# Dendrogram visualization. We visualize the titles of each paper next to the corresponding leaf to qualitatively evaluate the clustering.
#
# Changing the `color_threshold` kwarg in the call to `dendrogram()` will affect how the clusters are displayed by increasing or decreasing the
# minimum distance necessary for `dendrogram()` to color a cluster differently.

# %%
sys.setrecursionlimit(10000)
MAX_COPHENETIC_DIST = max(linkage_matrix[:,2]) * 0.39 # max distance between points to be considered together. can be tuned.
MAX_TITLE_LEN = 50

fig, ax = plt.subplots(figsize=(15, 80)) # set size
ax = dendrogram(linkage_matrix, orientation="right", color_threshold=MAX_COPHENETIC_DIST, leaf_font_size=4,
                labels=Summary.apply(lambda x: x if len(x) < MAX_TITLE_LEN else x[:MAX_TITLE_LEN  - 3] + "...").tolist())

plt.tick_params(axis= 'x', which='both',  bottom='off', top='off',labelbottom='off')

plt.tight_layout() #show plot with tight layout
plt.savefig('ward_clusters_all.png', dpi=300)

# %% [markdown]
#  Visualizing our cleaned bug data using WordCloud

# %% [markdown]
# # Analysis
#
# We now take the raw clusters achieved and use the silhouette score and elbow method to evaluate.

# %%
def silhouette_k(distance_matrix, linkage_matrix, max_k=20):
    scores = []
    for i in range(2, max_k+1):
        clusters = fcluster(linkage_matrix, i, criterion='maxclust')
        score = silhouette_score(distance_matrix, clusters, metric='precomputed')
        print("Silhouette score with {} clusters:".format(i), score)
        scores.append(score)
    plt.title("Silhouette score vs. number of clusters")
    plt.xlabel("# of clusters")
    plt.ylabel("Score (higher is better)")
    plt.plot(np.arange(2, max_k+1), scores)
    plt.show()
    return scores

# %%
np.fill_diagonal(dist, 0)
_ = silhouette_k(dist, linkage_matrix)
# Out:
# Silhouette score with 2 clusters: 0.017458570252201887
# Silhouette score with 3 clusters: 0.014129354355823723
# Silhouette score with 4 clusters: 0.020936517244530665
# Silhouette score with 5 clusters: 0.013474468674913852
# Silhouette score with 6 clusters: 0.01595145061350217
# Silhouette score with 7 clusters: 0.0129199125834904
# Silhouette score with 8 clusters: 0.01273379843641014
# Silhouette score with 9 clusters: 0.01252160752580411
# Silhouette score with 10 clusters: 0.0131985547829495
# Silhouette score with 11 clusters: 0.011070814394344073
# Silhouette score with 12 clusters: 0.009863079918670047
# Silhouette score with 13 clusters: 0.012322264672499788
# Silhouette score with 14 clusters: 0.010231899016136244
# Silhouette score with 15 clusters: 0.012020138471563907
# Silhouette score with 16 clusters: 0.014786092460779563
# Silhouette score with 17 clusters: 0.013185975015785615
# Silhouette score with 18 clusters: 0.015961527557261337
# Silhouette score with 19 clusters: 0.01559459899744194
# Silhouette score with 20 clusters: 0.01989839775447972

# %%
### Complete

# %%
dist = dist - dist.min() # get rid of some pesky floating point errors that give neg. distance
linkage_matrix = complete(dist) # replace with complete, single, or other scipy.cluster.hierarchical algorithms
# Out:
# C:\Users\GF\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py:356: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='complete', metric='euclidean')

# %%
## Visualization

# %%
sys.setrecursionlimit(10000)
MAX_COPHENETIC_DIST = max(linkage_matrix[:,2]) * 0.39 # max distance between points to be considered together. can be tuned.
MAX_TITLE_LEN = 50

fig, ax = plt.subplots(figsize=(15, 80)) # set size
ax = dendrogram(linkage_matrix, orientation="right", color_threshold=MAX_COPHENETIC_DIST, leaf_font_size=4,
                labels=Summary.apply(lambda x: x if len(x) < MAX_TITLE_LEN else x[:MAX_TITLE_LEN  - 3] + "...").tolist())

plt.tick_params(axis= 'x', which='both',  bottom='off', top='off',labelbottom='off')

plt.tight_layout() #show plot with tight layout
plt.savefig('ward_clusters_all.png', dpi=300)

# %% [markdown]
# # Analysis

# %%
def silhouette_k(distance_matrix, linkage_matrix, max_k=20):
    scores = []
    for i in range(2, max_k+1):
        clusters = fcluster(linkage_matrix, i, criterion='maxclust')
        score = silhouette_score(distance_matrix, clusters, metric='precomputed')
        print("Silhouette score with {} clusters:".format(i), score)
        scores.append(score)
    plt.title("Silhouette score vs. number of clusters")
    plt.xlabel("# of clusters")
    plt.ylabel("Score (higher is better)")
    plt.plot(np.arange(2, max_k+1), scores)
    plt.show()
    return scores

# %%
np.fill_diagonal(dist, 0)
_ = silhouette_k(dist, linkage_matrix)
# Out:
# Silhouette score with 2 clusters: 0.000677070336399297
# Silhouette score with 3 clusters: 0.0015454849598312216
# Silhouette score with 4 clusters: 0.008463636601722398
# Silhouette score with 5 clusters: 0.01030411189827235
# Silhouette score with 6 clusters: 0.01324532868667771
# Silhouette score with 7 clusters: 0.01551581935603721
# Silhouette score with 8 clusters: 0.014205485139012312
# Silhouette score with 9 clusters: 0.015970808626065664
# Silhouette score with 10 clusters: 0.01755452670616332
# Silhouette score with 11 clusters: 0.018841876719812828
# Silhouette score with 12 clusters: 0.019864579468383655
# Silhouette score with 13 clusters: 0.02027894663199446
# Silhouette score with 14 clusters: 0.02182008470784359
# Silhouette score with 15 clusters: 0.017397672272502197
# Silhouette score with 16 clusters: 0.01880487794799713
# Silhouette score with 17 clusters: 0.020213187760044587
# Silhouette score with 18 clusters: 0.020711518193832393
# Silhouette score with 19 clusters: 0.02269839028796464
# Silhouette score with 20 clusters: 0.02198426155810579

# %% [markdown]
# ### Ward

# %%
dist = dist - dist.min() # get rid of some pesky floating point errors that give neg. distance
linkage_matrix = ward(dist) # replace with complete, single, or other scipy.cluster.hierarchical algorithms
# Out:
# C:\Users\GF\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py:826: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %% [markdown]
# ## Visualization

# %%
sys.setrecursionlimit(10000)
MAX_COPHENETIC_DIST = max(linkage_matrix[:,2]) * 0.39 # max distance between points to be considered together. can be tuned.
MAX_TITLE_LEN = 50

fig, ax = plt.subplots(figsize=(15, 80)) # set size
ax = dendrogram(linkage_matrix, orientation="right", color_threshold=MAX_COPHENETIC_DIST, leaf_font_size=4,
                labels=Summary.apply(lambda x: x if len(x) < MAX_TITLE_LEN else x[:MAX_TITLE_LEN  - 3] + "...").tolist())

plt.tick_params(axis= 'x', which='both',  bottom='off', top='off',labelbottom='off')

plt.tight_layout() #show plot with tight layout
plt.savefig('ward_clusters_all.png', dpi=300)

# %% [markdown]
# # Analysis

# %%
def silhouette_k(distance_matrix, linkage_matrix, max_k=20):
    scores = []
    for i in range(2, max_k+1):
        clusters = fcluster(linkage_matrix, i, criterion='maxclust')
        score = silhouette_score(distance_matrix, clusters, metric='precomputed')
        print("Silhouette score with {} clusters:".format(i), score)
        scores.append(score)
    plt.title("Silhouette score vs. number of clusters")
    plt.xlabel("# of clusters")
    plt.ylabel("Score (higher is better)")
    plt.plot(np.arange(2, max_k+1), scores)
    plt.show()
    return scores

# %%
np.fill_diagonal(dist, 0)
_ = silhouette_k(dist, linkage_matrix)
# Out:
# Silhouette score with 2 clusters: 0.010115593665794906
# Silhouette score with 3 clusters: 0.016608789003014716
# Silhouette score with 4 clusters: 0.01779203324566621
# Silhouette score with 5 clusters: 0.019645288520818913
# Silhouette score with 6 clusters: 0.011602842251839432
# Silhouette score with 7 clusters: 0.013702679152136278
# Silhouette score with 8 clusters: 0.016185611594401607
# Silhouette score with 9 clusters: 0.018320316458988094
# Silhouette score with 10 clusters: 0.01974254489749323
# Silhouette score with 11 clusters: 0.01960352298389911
# Silhouette score with 12 clusters: 0.020537525555229637
# Silhouette score with 13 clusters: 0.02053758934023058
# Silhouette score with 14 clusters: 0.02202353079624119
# Silhouette score with 15 clusters: 0.021066400667728642
# Silhouette score with 16 clusters: 0.024583975955189862
# Silhouette score with 17 clusters: 0.02606167069210592
# Silhouette score with 18 clusters: 0.027845921787925696
# Silhouette score with 19 clusters: 0.029802390123722437
# Silhouette score with 20 clusters: 0.02996557405256707

# %% [markdown]
# ### Weighted

# %%
dist = dist - dist.min() # get rid of some pesky floating point errors that give neg. distance
linkage_matrix = ward(dist) # replace with complete, single, or other scipy.cluster.hierarchical algorithms
# Out:
# C:\Users\GF\anaconda3\lib\site-packages\scipy\cluster\hierarchy.py:826: ClusterWarning: scipy.cluster: The symmetric non-negative hollow observation matrix looks suspiciously like an uncondensed distance matrix
#   return linkage(y, method='ward', metric='euclidean')

# %% [markdown]
# ## Visualization

# %%
sys.setrecursionlimit(10000)
MAX_COPHENETIC_DIST = max(linkage_matrix[:,2]) * 0.39 # max distance between points to be considered together. can be tuned.
MAX_TITLE_LEN = 50

fig, ax = plt.subplots(figsize=(15, 80)) # set size
ax = dendrogram(linkage_matrix, orientation="right", color_threshold=MAX_COPHENETIC_DIST, leaf_font_size=4,
                labels=Summary.apply(lambda x: x if len(x) < MAX_TITLE_LEN else x[:MAX_TITLE_LEN  - 3] + "...").tolist())

plt.tick_params(axis= 'x', which='both',  bottom='off', top='off',labelbottom='off')

plt.tight_layout() #show plot with tight layout
plt.savefig('ward_clusters_all.png', dpi=300)

# %% [markdown]
# # Analysis

# %%
def silhouette_k(distance_matrix, linkage_matrix, max_k=20):
    scores = []
    for i in range(2, max_k+1):
        clusters = fcluster(linkage_matrix, i, criterion='maxclust')
        score = silhouette_score(distance_matrix, clusters, metric='precomputed')
        print("Silhouette score with {} clusters:".format(i), score)
        scores.append(score)
    plt.title("Silhouette score vs. number of clusters")
    plt.xlabel("# of clusters")
    plt.ylabel("Score (higher is better)")
    plt.plot(np.arange(2, max_k+1), scores)
    plt.show()
    return scores

# %%
np.fill_diagonal(dist, 0)
_ = silhouette_k(dist, linkage_matrix)
# Out:
# Silhouette score with 2 clusters: 0.010115593665794906
# Silhouette score with 3 clusters: 0.016608789003014716
# Silhouette score with 4 clusters: 0.01779203324566621
# Silhouette score with 5 clusters: 0.019645288520818913
# Silhouette score with 6 clusters: 0.011602842251839432
# Silhouette score with 7 clusters: 0.013702679152136278
# Silhouette score with 8 clusters: 0.016185611594401607
# Silhouette score with 9 clusters: 0.018320316458988094
# Silhouette score with 10 clusters: 0.01974254489749323
# Silhouette score with 11 clusters: 0.01960352298389911
# Silhouette score with 12 clusters: 0.020537525555229637
# Silhouette score with 13 clusters: 0.02053758934023058
# Silhouette score with 14 clusters: 0.02202353079624119
# Silhouette score with 15 clusters: 0.021066400667728642
# Silhouette score with 16 clusters: 0.024583975955189862
# Silhouette score with 17 clusters: 0.02606167069210592
# Silhouette score with 18 clusters: 0.027845921787925696
# Silhouette score with 19 clusters: 0.029802390123722437
# Silhouette score with 20 clusters: 0.02996557405256707
